# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets.samples_generator import make_blobs

# %%
# Read in the csv file
data = pd.read_csv("/Users/naaz.27khan/Desktop/project-3/Resources/cleaned_data.csv")
data
# Out:
#       Unnamed: 0             color       director_name  \
# 0              0             Color       James Cameron
# 1              1             Color      Gore Verbinski
# 2              2             Color          Sam Mendes
# 3              3             Color   Christopher Nolan
# 4              5             Color      Andrew Stanton
# 5              6             Color           Sam Raimi
# 6              7             Color        Nathan Greno
# 7              8             Color         Joss Whedon
# 8              9             Color         David Yates
# 9             10             Color         Zack Snyder
# 10            11             Color        Bryan Singer
# 11            12             Color        Marc Forster
# 12            13             Color      Gore Verbinski
# 13            14             Color      Gore Verbinski
# 14            15             Color         Zack Snyder
# 15            16             Color      Andrew Adamson
# ...

# %%
print(data.shape)
# Out:
# (3806, 28)

# %%
data, _ = make_blobs(n_samples=3806, centers=15,
                            cluster_std=0.70, random_state=0)

# %%
plt.scatter(data[:, 0], data[:, 1])
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10)

# Fit the model to the data
kmeans.fit(data)

# Use the data to predict the clusters
# save the predictions as `predicted_clusters`
predicted_clusters = kmeans.predict(data)

# %%
plt.scatter(data[:, 0], data[:, 1], c=predicted_clusters, s=50, cmap='viridis')
plt.show()

# %%
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
centers
# Out:
# array([[ 5.67238148,  0.55156253],
#        [-0.41437881,  4.11521493],
#        [-8.60473246, -8.29021298],
#        [-8.33950613,  7.8050384 ],
#        [-0.08738765,  8.06660234],
#        [ 9.55131336,  5.95615934],
#        [ 9.25389401, -2.35181663],
#        [ 1.19573811, -0.48549214],
#        [ 5.57053125,  7.42525239],
#        [-7.63038345,  2.77198574]])

# %%
plt.scatter(data[:, 0], data[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

plt.show()
