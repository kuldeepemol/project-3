# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

import keras
from keras.preprocessing import image
from keras.applications.xception import (
    Xception, preprocess_input, decode_predictions)
# Out:
# /Users/naaz.27khan/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = Xception(
    include_top=True,
    weights='imagenet')

# %%
image_size = (299, 299)

# %%
image_path = os.path.join("/Users/naaz.27khan/Desktop/project-3/actor1.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3)[0])
plt.imshow(img)
# Out:
# Predicted: [('n04356056', 'sunglasses', 0.63512427), ('n04355933', 'sunglass', 0.29696786), ('n04162706', 'seat_belt', 0.003905844)]

# %%
def predict(image_path):
    """Use Xception to label image"""
    img = image.load_img(image_path, target_size=image_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=3)[0])

# %%
image_path = os.path.join("/Users/naaz.27khan/Desktop/project-3/rob.jpg")
predict(image_path)
# Out:
# Predicted: [('n04350905', 'suit', 0.17623793), ('n02963159', 'cardigan', 0.04591184), ('n04591157', 'Windsor_tie', 0.045066956)]

# %%
image_path = os.path.join("/Users/naaz.27khan/Desktop/project-3/nic3.jpg")
predict(image_path)
# Out:
# Predicted: [('n03595614', 'jersey', 0.14947782), ('n04350905', 'suit', 0.11753097), ('n02883205', 'bow_tie', 0.031584036)]
